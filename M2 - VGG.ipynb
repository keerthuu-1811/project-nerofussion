# %% [markdown]
# ## VGG ARCHITECTURE

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow
import tensorflow as tf
print(tf.__version__)

import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU


from time import time
import numpy as np

from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,validation_split = 0.2)
train_data=train.flow_from_directory(directory = 'DATASET/TRAIN',target_size=(224,224),
                                     batch_size=32,class_mode='categorical')
# Out:
# Found 2100 images belonging to 6 classes.

# %%
test=ImageDataGenerator(rescale=1./255)
test_data=test.flow_from_directory(directory = 'DATASET/TEST',target_size=(224,224),
                                   batch_size=32,class_mode='categorical')
# Out:
# Found 2100 images belonging to 6 classes.

# %%
def vgg(input_shape, n_classes):
  
  input = Input(input_shape)
  
  x = Conv2D(64, 3, padding='same', activation='relu')(input)
  x = Conv2D(64, 3, padding='same', activation='relu')(x)
  x = MaxPool2D(2, strides=2, padding='same')(x)
  
  x = Conv2D(128, 3, padding='same', activation='relu')(x)
  x = Conv2D(128, 3, padding='same', activation='relu')(x)
  x = MaxPool2D(2, strides=2, padding='same')(x)
  
  x = Conv2D(256, 3, padding='same', activation='relu')(x)
  x = Conv2D(256, 3, padding='same', activation='relu')(x)
  x = Conv2D(256, 3, padding='same', activation='relu')(x)
  x = MaxPool2D(2, strides=2, padding='same')(x)
  
  x = Conv2D(512, 3, padding='same', activation='relu')(x)
  x = Conv2D(512, 3, padding='same', activation='relu')(x)
  x = Conv2D(512, 3, padding='same', activation='relu')(x)
  x = MaxPool2D(2, strides=2, padding='same')(x)
  
  x = Conv2D(512, 3, padding='same', activation='relu')(x)
  x = Conv2D(512, 3, padding='same', activation='relu')(x)
  x = Conv2D(512, 3, padding='same', activation='relu')(x)
  x = MaxPool2D(2, strides=2, padding='same')(x)
  
  x = Flatten()(x)
  x = Dense(4096, activation='relu')(x)
  x = Dense(4096, activation='relu')(x)
  
  output = Dense(n_classes, activation='softmax')(x)
  
  model = Model(input, output)
  model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy',tensorflow.keras.metrics.Precision()])
  return model

input_shape = 224, 224, 3
n_classes = 6

K.clear_session()
model = vgg(input_shape, n_classes)
model.summary()
# Out:
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 224, 224, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 64)      0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     73856
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 256)       0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 512)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 512)         0
#  g2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 6)                 24582
#
# =================================================================
# Total params: 134285126 (512.26 MB)
# Trainable params: 134285126 (512.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_path = "ALEXNET.h5"

from keras.callbacks import ModelCheckpoint

M = ModelCheckpoint(model_path, monitor='accuracy', verbose=1, save_best_only=True)

# %%
epochs = 50
batch_size = 512

# %%
#### Fitting the model
history = model.fit(
           train_data, steps_per_epoch=train_data.samples // batch_size, 
           epochs=epochs, 
           validation_data=test_data,validation_steps=test_data.samples // batch_size,
           callbacks=[M])
# Out:
# Epoch 1/50
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 4/4 [==============================] - ETA: 0s - loss: 1.9504 - accuracy: 0.1172 - precision: 0.1034
# Epoch 1: accuracy improved from -inf to 0.11719, saving model to ALEXNET.h5
# 4/4 [==============================] - 138s 35s/step - loss: 1.9504 - accuracy: 0.1172 - precision: 0.1034 - val_loss: 1.7917 - val_accuracy: 0.1875 - val_precision: 0.0000e+00
# Epoch 2/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7997 - accuracy: 0.1484 - precision: 0.0000e+00
# Epoch 2: accuracy improved from 0.11719 to 0.14844, saving model to ALEXNET.h5
# 4/4 [==============================] - 137s 36s/step - loss: 1.7997 - accuracy: 0.1484 - precision: 0.0000e+00 - val_loss: 1.7915 - val_accuracy: 0.2031 - val_precision: 0.0000e+00
# Epoch 3/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7908 - accuracy: 0.2109 - precision: 0.0000e+00
# Epoch 3: accuracy improved from 0.14844 to 0.21094, saving model to ALEXNET.h5
# 4/4 [==============================] - 150s 40s/step - loss: 1.7908 - accuracy: 0.2109 - precision: 0.0000e+00 - val_loss: 1.7970 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# Epoch 4/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7889 - accuracy: 0.2031 - precision: 0.0000e+00
# Epoch 4: accuracy did not improve from 0.21094
# 4/4 [==============================] - 107s 25s/step - loss: 1.7889 - accuracy: 0.2031 - precision: 0.0000e+00 - val_loss: 1.7993 - val_accuracy: 0.1172 - val_precision: 0.0000e+00
# Epoch 5/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7957 - accuracy: 0.1562 - precision: 0.0000e+00
# Epoch 5: accuracy did not improve from 0.21094
# 4/4 [==============================] - 98s 26s/step - loss: 1.7957 - accuracy: 0.1562 - precision: 0.0000e+00 - val_loss: 1.7892 - val_accuracy: 0.2031 - val_precision: 0.0000e+00
# Epoch 6/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7942 - accuracy: 0.1328 - precision: 0.0000e+00
# Epoch 6: accuracy did not improve from 0.21094
# 4/4 [==============================] - 114s 30s/step - loss: 1.7942 - accuracy: 0.1328 - precision: 0.0000e+00 - val_loss: 1.7886 - val_accuracy: 0.1953 - val_precision: 0.0000e+00
# Epoch 7/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7930 - accuracy: 0.1484 - precision: 0.0000e+00
# Epoch 7: accuracy did not improve from 0.21094
# 4/4 [==============================] - 135s 35s/step - loss: 1.7930 - accuracy: 0.1484 - precision: 0.0000e+00 - val_loss: 1.7996 - val_accuracy: 0.0859 - val_precision: 0.0000e+00
# Epoch 8/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7891 - accuracy: 0.1797 - precision: 0.0000e+00
# Epoch 8: accuracy did not improve from 0.21094
# 4/4 [==============================] - 118s 31s/step - loss: 1.7891 - accuracy: 0.1797 - precision: 0.0000e+00 - val_loss: 1.7898 - val_accuracy: 0.1875 - val_precision: 0.0000e+00
# Epoch 9/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7883 - accuracy: 0.1406 - precision: 0.0000e+00
# Epoch 9: accuracy did not improve from 0.21094
# 4/4 [==============================] - 115s 29s/step - loss: 1.7883 - accuracy: 0.1406 - precision: 0.0000e+00 - val_loss: 1.7927 - val_accuracy: 0.1875 - val_precision: 0.0000e+00
# Epoch 10/50
# 4/4 [==============================] - ETA: 0s - loss: 1.8034 - accuracy: 0.1172 - precision: 0.0000e+00
# Epoch 10: accuracy did not improve from 0.21094
# 4/4 [==============================] - 114s 30s/step - loss: 1.8034 - accuracy: 0.1172 - precision: 0.0000e+00 - val_loss: 1.7987 - val_accuracy: 0.1250 - val_precision: 0.0000e+00
# Epoch 11/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7899 - accuracy: 0.1562 - precision: 0.0000e+00
# Epoch 11: accuracy did not improve from 0.21094
# 4/4 [==============================] - 114s 30s/step - loss: 1.7899 - accuracy: 0.1562 - precision: 0.0000e+00 - val_loss: 1.7880 - val_accuracy: 0.1484 - val_precision: 0.0000e+00
# Epoch 12/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7901 - accuracy: 0.1875 - precision: 0.0000e+00
# Epoch 12: accuracy did not improve from 0.21094
# 4/4 [==============================] - 114s 30s/step - loss: 1.7901 - accuracy: 0.1875 - precision: 0.0000e+00 - val_loss: 1.7974 - val_accuracy: 0.1094 - val_precision: 0.0000e+00
# Epoch 13/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7945 - accuracy: 0.1562 - precision: 0.0000e+00
# Epoch 13: accuracy did not improve from 0.21094
# 4/4 [==============================] - 104s 26s/step - loss: 1.7945 - accuracy: 0.1562 - precision: 0.0000e+00 - val_loss: 1.7934 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# Epoch 14/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7932 - accuracy: 0.1379 - precision: 0.0000e+00
# Epoch 14: accuracy did not improve from 0.21094
# 4/4 [==============================] - 89s 23s/step - loss: 1.7932 - accuracy: 0.1379 - precision: 0.0000e+00 - val_loss: 1.7913 - val_accuracy: 0.1797 - val_precision: 0.0000e+00
# Epoch 15/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7939 - accuracy: 0.1484 - precision: 0.0000e+00
# Epoch 15: accuracy did not improve from 0.21094
# 4/4 [==============================] - 97s 25s/step - loss: 1.7939 - accuracy: 0.1484 - precision: 0.0000e+00 - val_loss: 1.7895 - val_accuracy: 0.1719 - val_precision: 0.0000e+00
# Epoch 16/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7917 - accuracy: 0.1724 - precision: 0.0000e+00
# Epoch 16: accuracy did not improve from 0.21094
# 4/4 [==============================] - 100s 26s/step - loss: 1.7917 - accuracy: 0.1724 - precision: 0.0000e+00 - val_loss: 1.7961 - val_accuracy: 0.1562 - val_precision: 0.0000e+00
# Epoch 17/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7920 - accuracy: 0.1641 - precision: 0.0000e+00
# Epoch 17: accuracy did not improve from 0.21094
# 4/4 [==============================] - 102s 25s/step - loss: 1.7920 - accuracy: 0.1641 - precision: 0.0000e+00 - val_loss: 1.7942 - val_accuracy: 0.2188 - val_precision: 0.0000e+00
# Epoch 18/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7917 - accuracy: 0.1719 - precision: 0.0000e+00
# Epoch 18: accuracy did not improve from 0.21094
# 4/4 [==============================] - 115s 32s/step - loss: 1.7917 - accuracy: 0.1719 - precision: 0.0000e+00 - val_loss: 1.7886 - val_accuracy: 0.1641 - val_precision: 0.0000e+00
# Epoch 19/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7957 - accuracy: 0.1172 - precision: 0.0000e+00
# Epoch 19: accuracy did not improve from 0.21094
# 4/4 [==============================] - 97s 24s/step - loss: 1.7957 - accuracy: 0.1172 - precision: 0.0000e+00 - val_loss: 1.7952 - val_accuracy: 0.1484 - val_precision: 0.0000e+00
# Epoch 20/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7930 - accuracy: 0.1172 - precision: 0.0000e+00
# Epoch 20: accuracy did not improve from 0.21094
# 4/4 [==============================] - 91s 24s/step - loss: 1.7930 - accuracy: 0.1172 - precision: 0.0000e+00 - val_loss: 1.7916 - val_accuracy: 0.1562 - val_precision: 0.0000e+00
# Epoch 21/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7949 - accuracy: 0.1328 - precision: 0.0000e+00
# Epoch 21: accuracy did not improve from 0.21094
# 4/4 [==============================] - 92s 24s/step - loss: 1.7949 - accuracy: 0.1328 - precision: 0.0000e+00 - val_loss: 1.7912 - val_accuracy: 0.2344 - val_precision: 0.0000e+00
# Epoch 22/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7919 - accuracy: 0.2031 - precision: 0.0000e+00
# Epoch 22: accuracy did not improve from 0.21094
# 4/4 [==============================] - 92s 24s/step - loss: 1.7919 - accuracy: 0.2031 - precision: 0.0000e+00 - val_loss: 1.7921 - val_accuracy: 0.1250 - val_precision: 0.0000e+00
# Epoch 23/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7918 - accuracy: 0.1641 - precision: 0.0000e+00
# Epoch 23: accuracy did not improve from 0.21094
# 4/4 [==============================] - 91s 24s/step - loss: 1.7918 - accuracy: 0.1641 - precision: 0.0000e+00 - val_loss: 1.7931 - val_accuracy: 0.1328 - val_precision: 0.0000e+00
# Epoch 24/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7917 - accuracy: 0.1875 - precision: 0.0000e+00
# Epoch 24: accuracy did not improve from 0.21094
# 4/4 [==============================] - 92s 24s/step - loss: 1.7917 - accuracy: 0.1875 - precision: 0.0000e+00 - val_loss: 1.7909 - val_accuracy: 0.1875 - val_precision: 0.0000e+00
# Epoch 25/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7919 - accuracy: 0.1562 - precision: 0.0000e+00
# Epoch 25: accuracy did not improve from 0.21094
# 4/4 [==============================] - 93s 24s/step - loss: 1.7919 - accuracy: 0.1562 - precision: 0.0000e+00 - val_loss: 1.7911 - val_accuracy: 0.1484 - val_precision: 0.0000e+00
# Epoch 26/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7916 - accuracy: 0.1953 - precision: 0.0000e+00
# Epoch 26: accuracy did not improve from 0.21094
# 4/4 [==============================] - 91s 24s/step - loss: 1.7916 - accuracy: 0.1953 - precision: 0.0000e+00 - val_loss: 1.7905 - val_accuracy: 0.1328 - val_precision: 0.0000e+00
# Epoch 27/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7906 - accuracy: 0.1875 - precision: 0.0000e+00
# Epoch 27: accuracy did not improve from 0.21094
# 4/4 [==============================] - 91s 24s/step - loss: 1.7906 - accuracy: 0.1875 - precision: 0.0000e+00 - val_loss: 1.7928 - val_accuracy: 0.1328 - val_precision: 0.0000e+00
# Epoch 28/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7942 - accuracy: 0.1641 - precision: 0.0000e+00
# Epoch 28: accuracy did not improve from 0.21094
# 4/4 [==============================] - 91s 24s/step - loss: 1.7942 - accuracy: 0.1641 - precision: 0.0000e+00 - val_loss: 1.7938 - val_accuracy: 0.1250 - val_precision: 0.0000e+00
# Epoch 29/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7895 - accuracy: 0.2188 - precision: 0.0000e+00
# Epoch 29: accuracy improved from 0.21094 to 0.21875, saving model to ALEXNET.h5
# 4/4 [==============================] - 113s 31s/step - loss: 1.7895 - accuracy: 0.2188 - precision: 0.0000e+00 - val_loss: 1.7909 - val_accuracy: 0.2188 - val_precision: 0.0000e+00
# Epoch 30/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7948 - accuracy: 0.1250 - precision: 0.0000e+00
# Epoch 30: accuracy did not improve from 0.21875
# 4/4 [==============================] - 95s 24s/step - loss: 1.7948 - accuracy: 0.1250 - precision: 0.0000e+00 - val_loss: 1.7928 - val_accuracy: 0.1328 - val_precision: 0.0000e+00
# Epoch 31/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7907 - accuracy: 0.1797 - precision: 0.0000e+00
# Epoch 31: accuracy did not improve from 0.21875
# 4/4 [==============================] - 94s 25s/step - loss: 1.7907 - accuracy: 0.1797 - precision: 0.0000e+00 - val_loss: 1.7899 - val_accuracy: 0.1953 - val_precision: 0.0000e+00
# Epoch 32/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7925 - accuracy: 0.1328 - precision: 0.0000e+00
# Epoch 32: accuracy did not improve from 0.21875
# 4/4 [==============================] - 93s 24s/step - loss: 1.7925 - accuracy: 0.1328 - precision: 0.0000e+00 - val_loss: 1.7922 - val_accuracy: 0.1562 - val_precision: 0.0000e+00
# Epoch 33/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7911 - accuracy: 0.1797 - precision: 0.0000e+00
# Epoch 33: accuracy did not improve from 0.21875
# 4/4 [==============================] - 92s 24s/step - loss: 1.7911 - accuracy: 0.1797 - precision: 0.0000e+00 - val_loss: 1.7899 - val_accuracy: 0.1641 - val_precision: 0.0000e+00
# Epoch 34/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7915 - accuracy: 0.1875 - precision: 0.0000e+00
# Epoch 34: accuracy did not improve from 0.21875
# 4/4 [==============================] - 92s 24s/step - loss: 1.7915 - accuracy: 0.1875 - precision: 0.0000e+00 - val_loss: 1.7923 - val_accuracy: 0.1953 - val_precision: 0.0000e+00
# Epoch 35/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7912 - accuracy: 0.1484 - precision: 0.0000e+00
# Epoch 35: accuracy did not improve from 0.21875
# 4/4 [==============================] - 92s 24s/step - loss: 1.7912 - accuracy: 0.1484 - precision: 0.0000e+00 - val_loss: 1.7941 - val_accuracy: 0.1953 - val_precision: 0.0000e+00
# Epoch 36/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7907 - accuracy: 0.1719 - precision: 0.0000e+00
# Epoch 36: accuracy did not improve from 0.21875
# 4/4 [==============================] - 93s 24s/step - loss: 1.7907 - accuracy: 0.1719 - precision: 0.0000e+00 - val_loss: 1.7925 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# Epoch 37/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7912 - accuracy: 0.1983 - precision: 0.0000e+00
# Epoch 37: accuracy did not improve from 0.21875
# 4/4 [==============================] - 84s 24s/step - loss: 1.7912 - accuracy: 0.1983 - precision: 0.0000e+00 - val_loss: 1.7919 - val_accuracy: 0.1719 - val_precision: 0.0000e+00
# Epoch 38/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7917 - accuracy: 0.1406 - precision: 0.0000e+00
# Epoch 38: accuracy did not improve from 0.21875
# 4/4 [==============================] - 94s 24s/step - loss: 1.7917 - accuracy: 0.1406 - precision: 0.0000e+00 - val_loss: 1.7906 - val_accuracy: 0.1797 - val_precision: 0.0000e+00
# Epoch 39/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7941 - accuracy: 0.1328 - precision: 0.0000e+00
# Epoch 39: accuracy did not improve from 0.21875
# 4/4 [==============================] - 93s 24s/step - loss: 1.7941 - accuracy: 0.1328 - precision: 0.0000e+00 - val_loss: 1.7907 - val_accuracy: 0.1719 - val_precision: 0.0000e+00
# Epoch 40/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7917 - accuracy: 0.2031 - precision: 0.0000e+00
# Epoch 40: accuracy did not improve from 0.21875
# 4/4 [==============================] - 99s 26s/step - loss: 1.7917 - accuracy: 0.2031 - precision: 0.0000e+00 - val_loss: 1.7916 - val_accuracy: 0.1641 - val_precision: 0.0000e+00
# Epoch 41/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7907 - accuracy: 0.1562 - precision: 0.0000e+00
# Epoch 41: accuracy did not improve from 0.21875
# 4/4 [==============================] - 104s 26s/step - loss: 1.7907 - accuracy: 0.1562 - precision: 0.0000e+00 - val_loss: 1.7926 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# Epoch 42/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7925 - accuracy: 0.2344 - precision: 0.0000e+00
# Epoch 42: accuracy improved from 0.21875 to 0.23438, saving model to ALEXNET.h5
# 4/4 [==============================] - 184s 54s/step - loss: 1.7925 - accuracy: 0.2344 - precision: 0.0000e+00 - val_loss: 1.7922 - val_accuracy: 0.1875 - val_precision: 0.0000e+00
# Epoch 43/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7888 - accuracy: 0.1641 - precision: 0.0000e+00
# Epoch 43: accuracy did not improve from 0.23438
# 4/4 [==============================] - 119s 28s/step - loss: 1.7888 - accuracy: 0.1641 - precision: 0.0000e+00 - val_loss: 1.7890 - val_accuracy: 0.1641 - val_precision: 0.0000e+00
# Epoch 44/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7934 - accuracy: 0.1406 - precision: 0.0000e+00
# Epoch 44: accuracy did not improve from 0.23438
# 4/4 [==============================] - 104s 27s/step - loss: 1.7934 - accuracy: 0.1406 - precision: 0.0000e+00 - val_loss: 1.7905 - val_accuracy: 0.1797 - val_precision: 0.0000e+00
# Epoch 45/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7908 - accuracy: 0.1797 - precision: 0.0000e+00
# Epoch 45: accuracy did not improve from 0.23438
# 4/4 [==============================] - 100s 26s/step - loss: 1.7908 - accuracy: 0.1797 - precision: 0.0000e+00 - val_loss: 1.7957 - val_accuracy: 0.1094 - val_precision: 0.0000e+00
# Epoch 46/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7918 - accuracy: 0.1953 - precision: 0.0000e+00
# Epoch 46: accuracy did not improve from 0.23438
# 4/4 [==============================] - 100s 26s/step - loss: 1.7918 - accuracy: 0.1953 - precision: 0.0000e+00 - val_loss: 1.7956 - val_accuracy: 0.1562 - val_precision: 0.0000e+00
# Epoch 47/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7960 - accuracy: 0.1094 - precision: 0.0000e+00
# Epoch 47: accuracy did not improve from 0.23438
# 4/4 [==============================] - 101s 26s/step - loss: 1.7960 - accuracy: 0.1094 - precision: 0.0000e+00 - val_loss: 1.7937 - val_accuracy: 0.1719 - val_precision: 0.0000e+00
# Epoch 48/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7922 - accuracy: 0.1328 - precision: 0.0000e+00
# Epoch 48: accuracy did not improve from 0.23438
# 4/4 [==============================] - 101s 26s/step - loss: 1.7922 - accuracy: 0.1328 - precision: 0.0000e+00 - val_loss: 1.7937 - val_accuracy: 0.1250 - val_precision: 0.0000e+00
# Epoch 49/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7932 - accuracy: 0.1797 - precision: 0.0000e+00
# Epoch 49: accuracy did not improve from 0.23438
# 4/4 [==============================] - 101s 26s/step - loss: 1.7932 - accuracy: 0.1797 - precision: 0.0000e+00 - val_loss: 1.7913 - val_accuracy: 0.1719 - val_precision: 0.0000e+00
# Epoch 50/50
# 4/4 [==============================] - ETA: 0s - loss: 1.7922 - accuracy: 0.1328 - precision: 0.0000e+00
# Epoch 50: accuracy did not improve from 0.23438
# 4/4 [==============================] - 100s 26s/step - loss: 1.7922 - accuracy: 0.1328 - precision: 0.0000e+00 - val_loss: 1.7905 - val_accuracy: 0.1328 - val_precision: 0.0000e+00

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'val_loss', 'val_accuracy', 'val_precision'])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 8))
plt.plot(history.history['accuracy'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['accuracy'][i]*100,2),xy=(i,history.history['accuracy'][i]))

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(history.history['loss'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['loss'][i]*100,2),xy=(i,history.history['loss'][i]))

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()
